# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [3, 4, 5, 6, 7]
y = [5, 1, 2, 4, 5]
plt.plot(x,y)

# %%
np.random.randint(1, 6, size=5)
# Out:
# array([3, 3, 4, 2, 3])

# %%
x = np.random.randn(100)
x.mean()
# Out:
# -0.005773050677952837

# %%
x+=37
x.mean()
# Out:
# 36.99422694932205

# %%
plt.plot(x)

# %%
y = np.random.randn(100)*5
(y.std(),y.mean())
# Out:
# (4.750535179159667, -0.183632944622157)

# %%
z = np.linspace(0, 4, 30)
a = np.sin(z)*3
plt.plot(z,a)

# %%
a = np.sin(z)+0.8*z + *np.random.randint(30)
plt.scatter(z,a)
# Out:
#   File "<ipython-input-19-a840e9200919>", line 1
#     a = np.sin(z)+0.8*z + *np.random.randint(30)
#                           ^
# SyntaxError: invalid syntax

# %%
# Write comments here after this '#' / Switch to markdown using Ctrl+m then m
# No. of '#' determine the size of the words
# Refer to documentation for more info

# %% [markdown]
# # This is a header
# ## Biggest
# ### Bigger
# #### Big

# %% [markdown]
# ### Markdown w/ order
#
# 1. lolololol
# 2. happy
# 3. fun

# %% [markdown]
# ### 超連結
#
# [成為Python數據達人](http://bit.ly/iWantPython)
#
# #[Link name in brackets]  (link here)

# %% [markdown]
# #Insert photos: ![name here] (file name here w/o brackets)
# ![lololol](粉專logo2.png)

# %% [markdown]
# ### LaTeX notation

# %% [markdown]
# Before:
# f(x) = 3x^2 + 2x + 1

# %%
#Add $ symbols to the front and the back of the equation e.g. $3x^2 + 2x + 1$

# %% [markdown]
# After:
# $f(x) = 3x^2 + 2x + 1$

# %% [markdown]
# $$L = \int_ 1^3 x^3-2x^2+5\,dx$$

# %% [markdown]
# ### 變數

# %%
a = 3
b = 8.1

# %%
print(a+b)

# %%
Sentence = 'Das ist ein buch.'
print(Sentence)

# %%
list('129873')

# %%
L = list(range(2, 10))
R = list(range(3, 11))
T = list(range(3, 50, 5))

# %%
T

# %%
L*3

# %%
L+R

# %%
fruit = {'apple': 'True', 'banana': 'False'}

# %%
fruit['grapes'] = 'True'

# %%
fruit

# %%
L[2:6]

# %% [markdown]
# ### 互動功能

# %%
def pipi():
    ham = input('拍拍')
    if ham == '拍拍':
        return('拍拍')

# %%
pipi()
# Out:
# 拍拍

# %%
def cube(x):
    return(x**3)

# %%
(5)
# Out:
# 125

# %%
from ipywidgets import interact

# %%
interact(cube, x=3.)
# Out:
# interactive(children=(FloatSlider(value=3.0, description='x', max=9.0, min=-3.0), Output()), _dom_classes=('wi…
# <function __main__.cube(x)>

# %%
interact(cube, x='hii')
# Out:
# interactive(children=(Text(value='hii', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.cube(x)>

# %%
interact(cube, x=['台北', '台中', '高雄'])
# Out:
# interactive(children=(Dropdown(description='x', options=('台北', '台中', '高雄'), value='台北'), Output()), _dom_class…
# <function __main__.cube(x)>

# %%
interact(cube, x={'台北':'1','台中':'2'})
# Out:
# interactive(children=(Dropdown(description='x', options={'台北': '1', '台中': '2'}, value='1'), Output()), _dom_cl…
# <function __main__.cube(x)>

# %%
from ipywidgets import interact_manual

# %%
def pipi2(x):
    return('拍拍')

# %%
interact_manual(pipi2, x='')

# %%
def move(n=1): #n=1為滑桿從1開始
    print(' '*n+'lala')

# %%
interact(move, n=(1,50))
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=50, min=1), Output()), _dom_classes=('widget-int…
# <function __main__.move(n=1)>

# %%
interact(move, n=(1,50));  #最後面加一個分號能夠隱藏<function __main__.move(n=1)>這段文字
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=50, min=1), Output()), _dom_classes=('widget-int…

# %%
def myplot(n=1):
    x = np.linspace(-3, 3, 100)
    y = np.sin(n*x)
    plt.plot(x,y)

# %%
interact(myplot, n=(1,30));

# %%
def add():
    grade = input('Your grade: ')
    grade = float(grade)+3
    print(grade)
    print("YAY")

# %%
sen = input(">> ")
if ("Coconut" in sen):
    print("The coconut nut is a giant nut")
else:
    print("no coconut...")

# %%
mag = 'Dora'
while (mag != 'bye'):
    print("拍拍")
    mag = input(">> ")
